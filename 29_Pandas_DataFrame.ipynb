# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranmohan3236/Pandas/blob/main/29_Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1  2.688402  0.180412
#    2  0.752984  1.887887
#    3 -0.629097 -0.705796
# G2 1  0.190847  0.388611
#    2 -1.150635  1.131083
#    3  0.867173 -0.589357

# %%
df.loc['G1']
# Out:
#           A         B
# 1  2.688402  0.180412
# 2  0.752984  1.887887
# 3 -0.629097 -0.705796

# %%
df.loc['G1'].loc[1]
# Out:
# A    2.688402
# B    0.180412
# Name: 1, dtype: float64

# %%
#naming the G1 and 1,2,3 box if you want
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    2.688402  0.180412
#        2    0.752984  1.887887
#        3   -0.629097 -0.705796
# G2     1    0.190847  0.388611
#        2   -1.150635  1.131083
#        3    0.867173 -0.589357

# %%
#how to grab values
df.loc['G2'].loc[2]['B']
# Out:
# 1.1310826245017742

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    2.688402  0.180412
#        2    0.752984  1.887887
#        3   -0.629097 -0.705796
# G2     1    0.190847  0.388611
#        2   -1.150635  1.131083
#        3    0.867173 -0.589357

# %%
df.loc['G1'] #same output
# Out:
#             A         B
# Num
# 1    2.688402  0.180412
# 2    0.752984  1.887887
# 3   -0.629097 -0.705796

# %%
df.xs('G1') #Same output
# Out:
#             A         B
# Num
# 1    2.688402  0.180412
# 2    0.752984  1.887887
# 3   -0.629097 -0.705796

# %%
df.xs(1,level='Num')
# Out:
#                A         B
# Groups
# G1      2.688402  0.180412
# G2      0.190847  0.388611
